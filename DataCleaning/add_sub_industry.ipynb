# %%
import pandas as pd

#Set the path for CSV files
cleaned_data_path = "resources\cleaned_data.csv"
industries_path = "resources\industries.csv"

# %%
# Read the CSV file into a DataFrame
cleaned_df = pd.read_csv(cleaned_data_path)
cleaned_df.head()
# Out:
#   ASX Code Security Group Code  \
# 0      1AD                 EQY
# 1      1AG                 EQY
# 2      1ST                 EQY
# 3      3DP                 EQY
# 4      3PL                 EQY
#
#                                     Issuer Full Name   Product Description  \
# 0  ADALTA LIMITED                                ...  ORDINARY
# 1  ALTERRA LIMITED                               ...  ORDINARY
# 2  1ST GROUP LIMITED                             ...  ORDINARY
# 3  POINTERRA LIMITED                             ...  ORDINARY
# 4  3P LEARNING LIMITED..                         ...  ORDINARY
#
#    Last Price($) Business Date  Year
# 0          0.280      20170630  2017
# 1          0.024      20170630  2017
# 2          0.026      20170628  2017
# 3          0.025      20170629  2017
# 4          1.045      20170630  2017

# %%
#Read the industry CSV file
industries_df = pd.read_csv(industries_path)
industries_df.head()
# Out:
#   ASX Code                                      Company Name  \
# 0      1AD                           Adalta Limited Ordinary
# 1      1AE             Aurora Energy Metals Limited Ordinary
# 2    1ADOA  Adalta Limited $0.03 Option Expiring 29-May-2024
# 3      14D                     1414 Degrees Limited Ordinary
# 4      1AG                          Alterra Limited Ordinary
#
#                          Sub-Industry
# 0    Biotechnology & Medical Research
# 1                             Uranium
# 2    Biotechnology & Medical Research
# 3   Electrical Components & Equipment
# 4  Environmental Services & Equipment

# %%
#Merging combined data CSV and industries CSV files adding the Sub Industry column
merged_df = cleaned_df.merge(industries_df, on=['ASX Code'], how='left')
merged_df
# Out:
#       ASX Code Security Group Code  \
# 0          1AD                 EQY
# 1          1AG                 EQY
# 2          1ST                 EQY
# 3          3DP                 EQY
# 4          3PL                 EQY
# ...        ...                 ...
# 14082      ZIM                 EQY
# 14083      ZIP                 EQY
# 14084      ZNC                 EQY
# 14085     ZYAU                 EQY
# 14086     ZYUS                 EQY
#
#                                         Issuer Full Name  \
# 0      ADALTA LIMITED                                ...
# 1      ALTERRA LIMITED                               ...
# 2      1ST GROUP LIMITED                             ...
# 3      POINTERRA LIMITED                             ...
# 4      3P LEARNING LIMITED..                         ...
# ...                                                  ...
# 14082  ZIMPLATS HOLDINGS LIMITED                     ...
# 14083  ZIPTEL LIMITED                                ...
# 14084  ZENITH MINERALS LIMITED                       ...
# 14085  ANZ ETFS S&P/ASX 300 HIGH YIELD PLUS ETF      ...
# 14086  ANZ ETFS S&P 500 HIGH YIELD LOW VOLATILITY ETF...
#
#         Product Description  Last Price($) Business Date  Year  \
# 0      ORDINARY                      0.280      20170630  2017
# 1      ORDINARY                      0.024      20170630  2017
# 2      ORDINARY                      0.026      20170628  2017
# 3      ORDINARY                      0.025      20170629  2017
# 4      ORDINARY                      1.045      20170630  2017
# ...                     ...            ...           ...   ...
# 14082  ORDINARY                      3.600      20160629  2016
# 14083  ORDINARY                      0.155      20160630  2016
# 14084  ORDINARY                      0.110      20160630  2016
# 14085  ETF UNITS                     9.590      20160629  2016
# 14086  ETF UNITS                    12.100      20160630  2016
#
#                                          Company Name  \
# 0                             Adalta Limited Ordinary
# 1                            Alterra Limited Ordinary
# 2                                                 NaN
# 3                          Pointerra Limited Ordinary
# 4                       3P Learning Limited. Ordinary
# ...                                               ...
# 14082       Zimplats Holdings Limited 10c US Ordinary
# 14083                        Zip Co Limited. Ordinary
# 14084                Zenith Minerals Limited Ordinary
# 14085          Global X S&P/ASX 200 High Dividend ETF
# 14086  Global X S&P 500 High Yield Low Volatility ETF
#
#                              Sub-Industry
# 0        Biotechnology & Medical Research
# 1      Environmental Services & Equipment
# 2                                     NaN
# 3                                Software
# 4                                Software
# ...                                   ...
# 14082          Precious Metals & Minerals
# 14083                    Consumer Lending
# 14084                  Integrated  Mining
# 14085                                 NaN
# 14086                                 NaN
#
# [14087 rows x 9 columns]

# %%
#Saving the final file as a CSV
merged_df.to_csv('resources\merged_industries.csv', index=False)
